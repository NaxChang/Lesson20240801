# %% [markdown]
# # 基本數值計算

# %%
1 + 2 + 3
# Out:
# 6

# %%
10 - 7
# Out:
# 3

# %%
4 * 5
# Out:
# 20

# %%
10 / 2
# Out:
# 5.0

# %%
max(1, -2, 5)
min(1, -2, 5)
# Out:
# -2

# %%
min([1, -2, 5])
# Out:
# -2

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
sum([1, 2, 3], 2)
# Out:
# 8

# %%
pow(2, 3)
# Out:
# 8

# %%
pow(2, 3, 5)
# Out:
# 3
